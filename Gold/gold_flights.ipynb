# %%
# %sql
CREATE SCHEMA IF NOT EXISTS flights_gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS flights_gold.gold_flights_f (
    FLIGHT_ID STRING,
    AIRLINE_KEY INT,
    ORIG_AIRPORT_KEY INT,
    DEST_AIRPORT_KEY INT,
    DATE_KEY INT,
    DEPARTURE_DELAY INT,
    ARRIVAL_DELAY INT,
    SECURITY_DELAY INT,
    AIRLINE_DELAY INT,
    LATE_AIRCRAFT_DELAY INT,
    WEATHER_DELAY INT,
    AIR_TIME INT,
    ELAPSED_TIME INT,
    DISTANCE INT,
    CANCELLED STRING,
    DIVERTED STRING
)
USING DELTA;
